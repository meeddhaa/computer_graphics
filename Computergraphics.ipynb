# %% [markdown]
# <a href="https://colab.research.google.com/github/meeddhaa/computer_graphics/blob/main/Computergraphics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculate the points between the starting point (2,3) and the ending point(10,8)

# %%
import matplotlib.pyplot as plt

def dda(x1, y1, x2, y2):
    points = []
    dx = x2 - x1
    dy = y2 - y1
    steps = int(max(abs(dx), abs(dy)))
    x_inc = dx / steps
    y_inc = dy / steps
    x, y = x1, y1
    for _ in range(steps + 1):
        px = round(x)
        py = round(y)
        points.append((float(f"{px:.2f}"), float(f"{py:.2f}")))
        x += x_inc
        y += y_inc
    return points


x1, y1 = 2, 3
x2, y2 = 10, 8
points = dda(x1, y1, x2, y2)

print("Calculated Points (Rounded to Integer):")
for p in points:
    print(p)

plt.figure(figsize=(6,6))
x_vals = [p[0] for p in points]
y_vals = [p[1] for p in points]

plt.plot(x_vals, y_vals, marker='o', color='purple')

for i, (x, y) in enumerate(points):
    label = f"P{i}({x},{y})"
    plt.text(x + 0.05, y + 0.05, label, fontsize=9)

plt.title("DDA Line Drawing")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# Calculated Points (Rounded to Integer):
# (2.0, 3.0)
# (3.0, 4.0)
# (4.0, 4.0)
# (5.0, 5.0)
# (6.0, 6.0)
# (7.0, 6.0)
# (8.0, 7.0)
# (9.0, 7.0)
# (10.0, 8.0)

# %%
#Calculate the points between the starting point (3, 5) and the ending point (11, 9). (mid-point)
import matplotlib.pyplot as plt
def midpoint_line(x1, y1, x2, y2):
    points = []
    dx = x2 - x1
    dy = y2 - y1
    d = dy - (dx / 2)
    x, y = x1, y1
    points.append((float(f"{x:.2f}"), float(f"{y:.2f}")))
    while x < x2:
        x += 1
        if d < 0:
            d = d + dy
        else:
            d = d + (dy - dx)
            y += 1
        points.append((float(f"{x:.2f}"), float(f"{y:.2f}")))
    return points
x1, y1 = 3, 5
x2, y2 = 11, 9
points = midpoint_line(x1, y1, x2, y2)
print("Calculated Points (Mid-Point Line Drawing):")
for p in points:
    print(p)
plt.figure(figsize=(6,6))
x_vals = [p[0] for p in points]
y_vals = [p[1] for p in points]
plt.plot(x_vals, y_vals, marker='o', color='green')
for i, (x, y) in enumerate(points):
    label = f"P{i}({x},{y})"
    plt.text(x + 0.05, y + 0.05, label, fontsize=9)
plt.title("Mid-Point Line Drawing Algorithm")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# Calculated Points (Mid-Point Line Drawing):
# (3.0, 5.0)
# (4.0, 6.0)
# (5.0, 6.0)
# (6.0, 7.0)
# (7.0, 7.0)
# (8.0, 8.0)
# (9.0, 8.0)
# (10.0, 9.0)
# (11.0, 9.0)

# %%
#Bresenham's Circle Drawing Algorithm
#Given the center point coordinates (2, 3) and the radius of 4, generate all the points to form the circle.

import matplotlib.pyplot as plt
import math

def bresenham_circle(xc, yc, r):
    points = []
    x = 0
    y = r
    d = 3 - 2 * r

    def plot_circle_points(xc, yc, x, y):
        pts = [
            (xc + x, yc + y),
            (xc - x, yc + y),
            (xc + x, yc - y),
            (xc - x, yc - y),
            (xc + y, yc + x),
            (xc - y, yc + x),
            (xc + y, yc - x),
            (xc - y, yc - x),
        ]
        for px, py in pts:
            points.append((float(f"{px:.2f}"), float(f"{py:.2f}")))

    while x <= y:
        plot_circle_points(xc, yc, x, y)
        if d < 0:
            d += 4 * x + 6
        else:
            d += 4 * (x - y) + 10
            y -= 1
        x += 1

    # Remove duplicates
    unique_points = []
    for p in points:
        if p not in unique_points:
            unique_points.append(p)

    return unique_points
# Circle center and radius
xc, yc = 0, 0
r = 6
points = bresenham_circle(xc, yc, r)
print("Calculated Points (Bresenham's Circle Drawing):")
for p in points:
    print(p)

# Sort points by angle for proper connection
points_sorted = sorted(points, key=lambda p: math.atan2(p[1] - yc, p[0] - xc))

# Plotting
plt.figure(figsize=(6,6))
x_vals = [p[0] for p in points_sorted]
y_vals = [p[1] for p in points_sorted]
# Close the loop
x_vals.append(x_vals[0])
y_vals.append(y_vals[0])

plt.plot(x_vals, y_vals, marker='o', color='purple')

# Annotate points
for i, (x, y) in enumerate(points_sorted):
    label = f"P{i}({x},{y})"
    plt.text(x + 0.2, y + 0.2, label, fontsize=8)

plt.title("Bresenham's Circle Drawing Algorithm (Connected)")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# Calculated Points (Bresenham's Circle Drawing):
# (0.0, 6.0)
# (0.0, -6.0)
# (6.0, 0.0)
# (-6.0, 0.0)
# (1.0, 6.0)
# (-1.0, 6.0)
# (1.0, -6.0)
# (-1.0, -6.0)
# (6.0, 1.0)
# (-6.0, 1.0)
# (6.0, -1.0)
# (-6.0, -1.0)
# (2.0, 6.0)
# (-2.0, 6.0)
# (2.0, -6.0)
# (-2.0, -6.0)
# (6.0, 2.0)
# (-6.0, 2.0)
# (6.0, -2.0)
# (-6.0, -2.0)
# (3.0, 5.0)
# (-3.0, 5.0)
# (3.0, -5.0)
# (-3.0, -5.0)
# (5.0, 3.0)
# (-5.0, 3.0)
# (5.0, -3.0)
# (-5.0, -3.0)
# (4.0, 4.0)
# (-4.0, 4.0)
# (4.0, -4.0)
# (-4.0, -4.0)

# %%
#Mid-Point Circle Drawing Algorithm
#Given the center point coordinates (4, 4) and the radius of 6, generate all the points to form the circle.
import matplotlib.pyplot as plt
import math

def midpoint_circle(xc, yc, r):
    points = []
    x = 0
    y = r
    p = 1 - r   # Initial decision parameter

    def plot_circle_points(xc, yc, x, y):
        pts = [
            (xc + x, yc + y),
            (xc - x, yc + y),
            (xc + x, yc - y),
            (xc - x, yc - y),
            (xc + y, yc + x),
            (xc - y, yc + x),
            (xc + y, yc - x),
            (xc - y, yc - x),
        ]
        for px, py in pts:
            if (px, py) not in points:
                points.append((float(f"{px:.2f}"), float(f"{py:.2f}")))

    while x <= y:
        plot_circle_points(xc, yc, x, y)
        if p < 0:
            p += 2 * x + 3
        else:
            p += 2 * (x - y) + 5
            y -= 1
        x += 1

    return points


# Circle center and radius
xc, yc = 4, 4
r = 6

points = midpoint_circle(xc, yc, r)

print("Calculated Points (Mid-Point Circle Drawing):")
for p in points:
    print(p)

# Sort points for proper circle plotting
points_sorted = sorted(points, key=lambda p: math.atan2(p[1] - yc, p[0] - xc))

# Plotting
plt.figure(figsize=(7,7))
x_vals = [p[0] for p in points_sorted]
y_vals = [p[1] for p in points_sorted]

# Close the loop
x_vals.append(x_vals[0])
y_vals.append(y_vals[0])
plt.plot(x_vals, y_vals, marker='o', color='blue')

# Annotate points
for i, (x, y) in enumerate(points_sorted):
    label = f"P{i}({x},{y})"
    plt.text(x + 0.2, y + 0.2, label, fontsize=8)

plt.title("Mid-Point Circle Drawing Algorithm")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# Calculated Points (Mid-Point Circle Drawing):
# (4.0, 10.0)
# (4.0, -2.0)
# (10.0, 4.0)
# (-2.0, 4.0)
# (5.0, 10.0)
# (3.0, 10.0)
# (5.0, -2.0)
# (3.0, -2.0)
# (10.0, 5.0)
# (-2.0, 5.0)
# (10.0, 3.0)
# (-2.0, 3.0)
# (6.0, 10.0)
# (2.0, 10.0)
# (6.0, -2.0)
# (2.0, -2.0)
# (10.0, 6.0)
# (-2.0, 6.0)
# (10.0, 2.0)
# (-2.0, 2.0)
# (7.0, 9.0)
# (1.0, 9.0)
# (7.0, -1.0)
# (1.0, -1.0)
# (9.0, 7.0)
# (-1.0, 7.0)
# (9.0, 1.0)
# (-1.0, 1.0)
# (8.0, 8.0)
# (0.0, 8.0)
# (8.0, 0.0)
# (0.0, 0.0)

# %%
#2D Transformation
#Given a square with coordinate points A(2,3), B(6,3), C(6,-1), D(2,-1). Applying the translation with distance 1 towards the x-axis and 1 towards the y-axis. Obtain the new coordinates of the square.




import matplotlib.pyplot as plt

A = (2, 3)
B = (6, 3)
C = (6, -1)
D = (2, -1)

tx, ty = 1, 1

A_new = (A[0] + tx, A[1] + ty)
B_new = (B[0] + tx, B[1] + ty)
C_new = (C[0] + tx, C[1] + ty)
D_new = (D[0] + tx, D[1] + ty)

original_x = [A[0], B[0], C[0], D[0], A[0]]
original_y = [A[1], B[1], C[1], D[1], A[1]]
translated_x = [A_new[0], B_new[0], C_new[0], D_new[0], A_new[0]]
translated_y = [A_new[1], B_new[1], C_new[1], D_new[1], A_new[1]]

plt.figure(figsize=(6, 6))
plt.plot(original_x, original_y, 'b-o', label='Original Square')
plt.plot(translated_x, translated_y, 'r-o', label='Translated Square')

points_original = [("A", A), ("B", B), ("C", C), ("D", D)]
points_new = [("A'", A_new), ("B'", B_new), ("C'", C_new), ("D'", D_new)]

for name, coord in points_original:
    plt.text(coord[0] - 0.3, coord[1] + 0.3,
             f"{name}({coord[0]}, {coord[1]})", fontsize=10, color='purple')

for name, coord in points_new:
    plt.text(coord[0] - 0.3, coord[1] + 0.3,
             f"{name}({coord[0]}, {coord[1]})", fontsize=10, color='yellow')

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.title('2D Translation of a Square')
plt.axis('equal')
plt.show()

print("New coordinates after translation:")
print(f"A' = {A_new}")
print(f"B' = {B_new}")
print(f"C' = {C_new}")
print(f"D' = {D_new}")
# Out:
# New coordinates after translation:
# A' = (3, 4)
# B' = (7, 4)
# C' = (7, 0)
# D' = (3, 0)

# %%
#Scaling
#Question:
#Given a square object with coordinates A(0,4), B(4,4), C(4,0), D(0,0). Applying the scaling parameter 2 towards the x-axis and 3 towards the y-axis. Obtain the new coordinates of the object.

import matplotlib.pyplot as plt
A = (0, 4)
B = (4, 4)
C = (4, 0)
D = (0, 0)
sx, sy = 2, 3
A_new = (A[0] * sx, A[1] * sy)
B_new = (B[0] * sx, B[1] * sy)
C_new = (C[0] * sx, C[1] * sy)
D_new = (D[0] * sx, D[1] * sy)

original_x = [A[0], B[0], C[0], D[0], A[0]]
original_y = [A[1], B[1], C[1], D[1], A[1]]
scaled_x = [A_new[0], B_new[0], C_new[0], D_new[0], A_new[0]]
scaled_y = [A_new[1], B_new[1], C_new[1], D_new[1], A_new[1]]

plt.figure(figsize=(6, 6))
plt.plot(original_x, original_y, 'b-o', label='Original Square')
plt.plot(scaled_x, scaled_y, 'r-o', label='Scaled Square')

plt.text(A[0], A[1], f"A{A}", fontsize=9, color='blue', ha='right')
plt.text(B[0], B[1], f"B{B}", fontsize=9, color='blue', ha='left')
plt.text(C[0], C[1], f"C{C}", fontsize=9, color='blue', ha='left')
plt.text(D[0], D[1], f"D{D}", fontsize=9, color='blue', ha='right')

plt.text(A_new[0], A_new[1], f"A'{A_new}", fontsize=9, color='red', ha='right')
plt.text(B_new[0], B_new[1], f"B'{B_new}", fontsize=9, color='red', ha='left')
plt.text(C_new[0], C_new[1], f"C'{C_new}", fontsize=9, color='red', ha='left')
plt.text(D_new[0], D_new[1], f"D'{D_new}", fontsize=9, color='red', ha='right')

plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.title('2D Scaling of a Square')
plt.axis('equal')
plt.show()

print("New coordinates after scaling:")
print(f"A' = {A_new}")
print(f"B' = {B_new}")
print(f"C' = {C_new}")
print(f"D' = {D_new}")
# Out:
# New coordinates after scaling:
# A' = (0, 12)
# B' = (8, 12)
# C' = (8, 0)
# D' = (0, 0)

# %%
#Rotation
#Question:
 #Given a triangle with corner coordinates (0,0), (3,0), (2,3). Rotate the triangle by 90° anticlockwise and find the new coordinates.

import matplotlib.pyplot as plt

A = (0, 0)
B = (3, 0)
C = (2, 3)

def rotate_90_ccw(x, y):
    return -y, x
A_new = rotate_90_ccw(*A)
B_new = rotate_90_ccw(*B)
C_new = rotate_90_ccw(*C)

orig_x = [A[0], B[0], C[0], A[0]]
orig_y = [A[1], B[1], C[1], A[1]]
rot_x = [A_new[0], B_new[0], C_new[0], A_new[0]]
rot_y = [A_new[1], B_new[1], C_new[1], A_new[1]]


plt.figure(figsize=(6,6))
plt.plot(orig_x, orig_y, 'b-o', label='Original Triangle')
plt.plot(rot_x, rot_y, 'r-o', label="Rotated Triangle (90° CCW)")


plt.text(A[0], A[1], f"A{A}", fontsize=10, color='blue', ha='right')
plt.text(B[0], B[1], f"B{B}", fontsize=10, color='blue', ha='right')
plt.text(C[0], C[1], f"C{C}", fontsize=10, color='blue', ha='right')

plt.text(A_new[0], A_new[1], f"A'{A_new}", fontsize=10, color='red', ha='left')
plt.text(B_new[0], B_new[1], f"B'{B_new}", fontsize=10, color='red', ha='left')
plt.text(C_new[0], C_new[1], f"C'{C_new}", fontsize=10, color='red', ha='left')


plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.title('Rotation of a Triangle (90° Anticlockwise)')
plt.axis('equal')
plt.show()

print("New coordinates after rotation:")
print(f"A' = {A_new}")
print(f"B' = {B_new}")
print(f"C' = {C_new}")
# Out:
# New coordinates after rotation:
# A' = (0, 0)
# B' = (0, 3)
# C' = (-3, 2)

# %%
#Reflection
#Question:
#Given a triangle with coordinate points A = (4, 5) ,B = (7, 5) ,C = (6, 7) . Apply the reflection along the x-axis and y-axis. Obtain the new coordinates of the object.
import matplotlib.pyplot as plt

A = (4, 5)
B = (7, 5)
C = (6, 7)
def reflect_x(x, y):
    return x, -y
def reflect_y(x, y):
    return -x, y
A_x = reflect_x(*A)
B_x = reflect_x(*B)
C_x = reflect_x(*C)

A_y = reflect_y(*A)
B_y = reflect_y(*B)
C_y = reflect_y(*C)

orig_x = [A[0], B[0], C[0], A[0]]
orig_y = [A[1], B[1], C[1], A[1]]

xaxis_x = [A_x[0], B_x[0], C_x[0], A_x[0]]
xaxis_y = [A_x[1], B_x[1], C_x[1], A_x[1]]

yaxis_x = [A_y[0], B_y[0], C_y[0], A_y[0]]
yaxis_y = [A_y[1], B_y[1], C_y[1], A_y[1]]
plt.figure(figsize=(7,7))
plt.plot(orig_x, orig_y, 'b-o', label='Original Triangle')
plt.text(A[0], A[1], f"A{A}", fontsize=9, ha='right')
plt.text(B[0], B[1], f"B{B}", fontsize=9, ha='right')
plt.text(C[0], C[1], f"C{C}", fontsize=9, ha='right')

plt.plot(xaxis_x, xaxis_y, 'r-o', label="Reflected along X-axis")
plt.text(A_x[0], A_x[1], f"A'({A_x[0]}, {A_x[1]})", fontsize=9, ha='right')
plt.text(B_x[0], B_x[1], f"B'({B_x[0]}, {B_x[1]})", fontsize=9, ha='right')
plt.text(C_x[0], C_x[1], f"C'({C_x[0]}, {C_x[1]})", fontsize=9, ha='right')

plt.plot(yaxis_x, yaxis_y, 'g-o', label="Reflected along Y-axis")
plt.text(A_y[0], A_y[1], f"A''({A_y[0]}, {A_y[1]})", fontsize=9, ha='right')
plt.text(B_y[0], B_y[1], f"B''({B_y[0]}, {B_y[1]})", fontsize=9, ha='right')
plt.text(C_y[0], C_y[1], f"C''({C_y[0]}, {C_y[1]})", fontsize=9, ha='right')

plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.title('Reflection of a Triangle along X-axis and Y-axis')
plt.axis('equal')
plt.show()

print("Reflection along X-axis:")
print(f"A' = {A_x}")
print(f"B' = {B_x}")
print(f"C' = {C_x}")

print("\nReflection along Y-axis:")
print(f"A'' = {A_y}")
print(f"B'' = {B_y}")
print(f"C'' = {C_y}")
# Out:
# Reflection along X-axis:
# A' = (4, -5)
# B' = (7, -5)
# C' = (6, -7)
#
# Reflection along Y-axis:
# A'' = (-4, 5)
# B'' = (-7, 5)
# C'' = (-6, 7)

# %%
#Shearing
#Question:
 #Given a triangle with coordinate points (1,1), (0,0), and (1,0). Apply the shearing parameter 2 on the x-axis and 2 on the y-axis. Find out the new coordinate points of the object.
import matplotlib.pyplot as plt

O = (0, 0)
B = (2, 0)
A = (2, 2)

def shear_x(point, shx):
    x, y = point
    return x + shx * y, y

def shear_y(point, shy):
    x, y = point
    return x, y + shy * x

Shx = 2
Shy = 2

O_x = shear_x(O, Shx)
B_x = shear_x(B, Shx)
A_x = shear_x(A, Shx)
O_y = shear_y(O, Shy)
B_y = shear_y(B, Shy)
A_y = shear_y(A, Shy)

orig_x = [O[0], B[0], A[0], O[0]]
orig_y = [O[1], B[1], A[1], O[1]]

shear_x_x = [O_x[0], B_x[0], A_x[0], O_x[0]]
shear_x_y = [O_x[1], B_x[1], A_x[1], O_x[1]]

shear_y_x = [O_y[0], B_y[0], A_y[0], O_y[0]]
shear_y_y = [O_y[1], B_y[1], A_y[1], O_y[1]]

def annotate_points(points, names, ax):
    for (x, y), name in zip(points, names):
        ax.text(x + 0.05, y + 0.05, f"{name}({x}, {y})", fontsize=8)

plt.figure(figsize=(10, 4))

ax1 = plt.subplot(1, 2, 1)
ax1.plot(orig_x, orig_y, 'bo-', label='Original')
ax1.plot(shear_x_x, shear_x_y, 'ro-', label=f'Sheared in X-axis (Shx={Shx})')
ax1.axhline(0, color='gray', linewidth=0.5)
ax1.axvline(0, color='gray', linewidth=0.5)
ax1.set_title("Shearing in X-axis")
ax1.axis('equal')
ax1.grid(True)
ax1.legend()

annotate_points([O, B, A], ["O", "B", "A"], ax1)
annotate_points([O_x, B_x, A_x], ["O'", "B'", "A'"], ax1)

ax2 = plt.subplot(1, 2, 2)
ax2.plot(orig_x, orig_y, 'bo-', label='Original')
ax2.plot(shear_y_x, shear_y_y, 'ro-', label=f'Sheared in Y-axis (Shy={Shy})')
ax2.axhline(0, color='gray', linewidth=0.5)
ax2.axvline(0, color='gray', linewidth=0.5)
ax2.set_title("Shearing in Y-axis")
ax2.axis('equal')
ax2.grid(True)
ax2.legend()

annotate_points([O, B, A], ["O", "B", "A"], ax2)
annotate_points([O_y, B_y, A_y], ["O'", "B'", "A'"], ax2)

plt.show()

print("Shearing in X-axis:")
print(f"O' = {O_x}")
print(f"B' = {B_x}")
print(f"A' = {A_x}")

print("\nShearing in Y-axis:")
print(f"O' = {O_y}")
print(f"B' = {B_y}")
print(f"A' = {A_y}")
# Out:
# Shearing in X-axis:
# O' = (0, 0)
# B' = (2, 0)
# A' = (6, 2)
#
# Shearing in Y-axis:
# O' = (0, 0)
# B' = (2, 4)
# A' = (2, 6)
